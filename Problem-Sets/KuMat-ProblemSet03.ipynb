# %% [markdown]
# # Problem Set 03 - Kuliah Teori Kuantum Material
#
# ## Nama: Tulis Nama Lengkap
# ## NIM: Tulis NIM

# %% [markdown]
# ### Instruksi Pengerjaan:
#
# - Bagi yang menguasai penulisan dokumen dengan Jupyter Notebook, sangat disarankan untuk langsung mengerjakan seluruh soal pada kolom jawaban yang disediakan pada Jupyter Notebook ini. Saat membuka Jupyter Notebook, komputer harus **terhubung** dengan internet karena ada gambar pada soal yang merujuk ke tautan eksternal.
#
# - Mahasiswa yang tidak sanggup menulis dengan Jupyter Notebook, boleh menggunakan perangkat lunak lainnya (Word/LaTeX/dll.) dalam mengerjakan Problem Set ini. Boleh juga menggunakan tulisan tangan dan difoto/*scan*.
#
# - Jawaban **wajib** dikirimkan melalui email ahmad.ridwan.tresna.nugraha@brin.go.id **atau** art.nugraha@gmail.com, paling lambat pada **21 November 2025, pukul 23.59 WIB**.
#
# - Selama pengerjaan, mahasiswa boleh melihat apapun, referensi dari buku, catatan kuliah, internet, *AI tools*, ataupun teman yang dianggap lebih jago.
#
# - **Kerja sama antarmahasiswa sangat dibolehkan** dalam pengerjaan Problem Set ini. Namun, **DILARANG KERAS** menyalin jawaban apa adanya dari teman yang lain.
#
# - Jika ada indikasi seorang mahasiswa menyalin jawaban yang sama persis, maka mahasiswa yang menyontek maupun yang disontek akan sama-sama diberi nilai 0 untuk seluruh Problem Set ini.

# %% [markdown]
# ### Aturan Penilaian:
#
# - Setiap soal kali ini akan dinilai secara "**proporsional**" sesuai benar tidaknya satu langkah ke langkah berikutnya untuk mencapai jawaban yang diharapkan.
#
# - *Nilai maksimum* setiap soal adalah *25 poin*. Jika salah total, nilainya 0, tetapi jika ada langkah yang benar, ada kemungkinan setiap soal dinilai antara 0-25.
#
# - **Nilai total maksimal** dari mengerjakan seluruh Soal 1-4 adalah **100 poin**, sedangkan **nilai minimal** adalah **0 poin**.

# %% [markdown]
# ***

# %% [markdown]
# # Soal 1
#
# (a) (maks. 15 poin) Buktikan **teorema Hohenberg-Kohn I dan II**.
#
# (b) (maks. 10 poin) Berdasarkan teorema Hohenberg-Kohn I dan II, turunkanlah **persamaan Kohn-Sham** yang menjadi dasar dari *density functional theory* (DFT).

# %% [markdown]
# ## Jawaban 1:
#
# Tulis jawabanmu di sini.

# %% [markdown]
# # Soal 2
#
# (a) (maks. 10 poin) Turunkan formula untuk koefisien absorpsi (*absorption coefficient*) $\alpha$ dinyatakan dalam bagian riil dan bagian imajiner fungsi dielektrik $\epsilon$. Sebagai petunjuk, di GitHub repositori ini ada catatan terpisah (koefisien-absorpsi-dari-fungsi-dielektrik.pdf) yang memberikan penjelasan lengkapnya. Sebetulnya tinggal pelajari, pahami, dan salin ulang.
#
# (b) (maks. 10 poin) Turunkan formula *Fermi's golden rule* berdasarkan teori gangguan bergantung waktu (*time-dependent perturbation theory*).
#
# (c) (maks. 5 poin) Secara kualitatif, berikan penjelasan fenomena absorpsi cahaya oleh suatu material semikonduktor, bagaimana peluang absorpsi terbesar dapat terjadi sesuai *Fermi's golden rule*.

# %% [markdown]
# ## Jawaban 2:
#
# Tulis jawabanmu di sini.

# %% [markdown]
# ***

# %% [markdown]
# # Soal 3
#
# (a) (maks. 20 poin) Dengan menggunakan Quantum ESPRESSO, buatlah perhitungan pita energi (*band structure*) yang menunjukkan plot $E$ terhadap $k$ untuk material *monolayer* $\text{MoS}_2$. Gambar hubungan dispersi energi $E$ terhadap $k$ perlu diberikan pada titik-titik simetri tinggi (*high-symmetry point*) yang relevan di kasus material ini. Seluruh *input files* yang dibutuhkan (`scf.in`, `nscf.in`, dan `bands.in`) perlu ditunjukkan dalam jawaban.
#
# (b) (maks. 5 poin) Berikan analisis sederhana berdasarkan gambar pita energi yang sudah diperoleh, apa sifat listrik dari material $\text{MoS}_2$? Berapa besar *band gap* yang diperoleh?

# %% [markdown]
# ## Jawaban 3:
#
# Tulis jawabanmu di sini.

# %% [markdown]
# ***

# %% [markdown]
# # Soal 4
#
# (a) (maks. 20 poin) Dengan menggunakan Quantum ESPRESSO, lanjutkan perhitungan dari soal (3) untuk memperoleh koefisien absorpsi (*absorption coefficient*) $\alpha$ dari material *monolayer* $\text{MoS}_2$. Rentang energi foton di sumbu horizontal cukup dibuat dalam kisaran $0$-$5$ eV saja. Seluruh *input files* yang dibutuhkan perlu ditunjukkan dalam jawaban.
#
# (b) (maks. 5 poin) Berikan analisis sederhana berdasarkan gambar koefisien absorpsi yang telah diperoleh, material *monolayer* $\text{MoS}_2$ ini bagus menyerap cahaya pada rentang spektrum apa?

# %% [markdown]
# ## Jawaban 4:
#
# Tulis jawabanmu di sini.
